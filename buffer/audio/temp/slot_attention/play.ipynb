# %%
import os
import  sys
sys.path.append('/home/lev/slot_attention')

from data import MusanSynth

# %%
transforms = []
musan = MusanSynth(transforms=transforms, path="/home/lev/datasets/musan/synth_mel_train")

# %%
import matplotlib.pyplot as plt
plt.imshow(musan.__getitem__(140)[0])
